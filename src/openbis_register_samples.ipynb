# %% [markdown]
# # Register iNat observations in openBIS using pyBIS
# Demo notebook to import iNat observation in CSV file into openBIS. The CSV file is output generated by `inat_fetcher.py`.

# %%
import pandas as pd
import getpass, math
from datetime import datetime
from pybis import Openbis

# %% [markdown]
# ### 1. Connect to openBIS

# %%
server_url = 'https://openbis-dbgi.labnotebook.ch/' # URL of the openBIS server
user_name = 'hluetcke_admin' # user login for openBIS server

# further openBIS specific info
sample_type = 'OBSERVATION'
space = 'MATERIALS'
collection = '/MATERIALS/SAMPLES/SAMPLES_EXP_5'

# %%
o = Openbis(server_url, verify_certificates=False)

# %%
if o.is_session_active():
    print(f"Session is active and token is {o.token}")
else:
    password = getpass.getpass()
    o.login(user_name, password, save_token=True)   # save the session token in ~/.pybis/example.com.token
    del password
    print(f"Session is active: {o.is_session_active()} and token is {o.token}")

# %% [markdown]
# ### 2. Read CSV file

# %%
csv_file = '../data/out/test_inat_output_hl_short.csv'

df = pd.read_csv(csv_file)

properties_csv = df.columns.tolist()

# %% [markdown]
# ### 3. Register new samples
# Todo: option for updating existing samples

# %%
def get_openbis_properties(o, row, properties):
    # get properties for openBIS sample
    properties_ob = {}
    for prop in properties:
        val_ob = row[prop]
        prop_ob = prop
        if prop == 'id':
            prop_ob = 'observation_id'
        elif prop.startswith('observed_on_details') or prop.startswith('created_at_details'):
            continue
        elif prop.startswith('ofvs'):
            if prop == 'ofvs.15466':
                prop_ob = 'emi_external_id'
                prop = 'emi_external_id' 
            else:
                continue
        elif "." in prop:
            prop_ob = prop.replace('.','_')
    
        if is_nan(val_ob): # NaN causes error. This should be fixed in pyBIS.
            val_ob = 0

        # get expected data type for the property in openBIS
        # TODO: this should happen only once, not for every sample!
        ob_dataType = o.get_property_type(prop_ob).dataType

        if ob_dataType == 'HYPERLINK' and val_ob == 0:
            val_ob = None

        if ob_dataType == 'INTEGER':
            val_ob = int(float(val_ob))
         
        properties_ob[prop_ob] = val_ob

        if prop == 'observed_on':
            properties_ob['time_observed_at'] = val_ob

    return properties_ob

# %%
def is_nan(x):
    return (x != x)

# %%
def check_if_sample_registered(row, samples):
    # check if a sample with observation_id has been registered before
    if samples.df.shape[0] > 0:
        tf = samples.df['OBSERVATION_ID'] == str(row['id'])
        tf = tf.any()
    else:
        tf = False

    return tf

# %%
samples = o.get_samples(type=sample_type, collection=collection, props='observation_id')
break_tf = False
registered_samples = 0
updated_samples = 0
for index, row in df.iterrows():

    tf = check_if_sample_registered(row, samples)
    
    if tf:
        print(f"{row['id']} - sample has been registered before")
        # option to update sample metadata
        break
        updated_samples = updated_samples + 1
    else:
        print(f"{row['id']} - sample has not been registered before. registering now ...")

        properties_ob = get_openbis_properties(o, row, properties_csv)

        sample = o.new_sample(
            type       = sample_type,
            space      = space,
            experiment = collection,
            props      = properties_ob
        )
        sample.save()
        print('sample has been registered with code ' + sample.code)
        registered_samples = registered_samples + 1

        # if registered_samples >= 20:
        #     break_tf = True
    
    if break_tf:
        break

print(f"Registered {registered_samples} samples.")
print(f"Updated {updated_samples} samples.")
# Out:
# 109442071 - sample has been registered before
# Registered 0 samples.
# Updated 0 samples.

# %%
samples.df
# Out:
#                    permId              identifier     registrationDate  \
# 0  20231130144435315-1260  /MATERIALS/SAMPLES/O59  2023-11-30 14:44:35
# 1  20231130144436455-1261  /MATERIALS/SAMPLES/O60  2023-11-30 14:44:36
# 2  20231130144436810-1262  /MATERIALS/SAMPLES/O61  2023-11-30 14:44:37
# 3  20231130144437270-1263  /MATERIALS/SAMPLES/O62  2023-11-30 14:44:37
# 4  20231130144438265-1264  /MATERIALS/SAMPLES/O63  2023-11-30 14:44:38
# 5  20231130144438777-1265  /MATERIALS/SAMPLES/O64  2023-11-30 14:44:39
# 6  20231130144439211-1266  /MATERIALS/SAMPLES/O65  2023-11-30 14:44:39
# 7  20231130144439633-1267  /MATERIALS/SAMPLES/O66  2023-11-30 14:44:40
# 8  20231130144440124-1268  /MATERIALS/SAMPLES/O67  2023-11-30 14:44:40
# 9  20231130144440506-1269  /MATERIALS/SAMPLES/O68  2023-11-30 14:44:41
#
#       modificationDate         type     registrator        modifier  \
# 0  2023-11-30 14:44:35  OBSERVATION  hluetcke_admin  hluetcke_admin
# 1  2023-11-30 14:44:36  OBSERVATION  hluetcke_admin  hluetcke_admin
# 2  2023-11-30 14:44:37  OBSERVATION  hluetcke_admin  hluetcke_admin
# 3  2023-11-30 14:44:37  OBSERVATION  hluetcke_admin  hluetcke_admin
# 4  2023-11-30 14:44:38  OBSERVATION  hluetcke_admin  hluetcke_admin
# 5  2023-11-30 14:44:39  OBSERVATION  hluetcke_admin  hluetcke_admin
# 6  2023-11-30 14:44:39  OBSERVATION  hluetcke_admin  hluetcke_admin
# 7  2023-11-30 14:44:40  OBSERVATION  hluetcke_admin  hluetcke_admin
# 8  2023-11-30 14:44:40  OBSERVATION  hluetcke_admin  hluetcke_admin
# 9  2023-11-30 14:44:41  OBSERVATION  hluetcke_admin  hluetcke_admin
#
#   OBSERVATION_ID
# 0      109442071
# 1      110560140
# 2      110561024
# 3      112079178
# 4      112079181
# 5      112079182
# 6      117770383
# 7      117770414
# 8      117770416
# 9      117770434

# %%
type(row['id'])
# Out:
# int

# %%
# get openBIS permId to retrieve the sample
permId = samples.df.loc[samples.df['OBSERVATION_ID'] == str(row['id']), 'permId'].iloc[0]
sample_ob = o.get_sample(permId)

# %%
sample_ob.props
# Out:
# property                                        value
# ----------------------------------------------  ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# observation_id                                  109442071
# quality_grade                                   casual
# time_observed_at                                2022-03-25 10:33:03 +0100
# taxon_geoprivacy                                0
# annotations                                     []
# uuid                                            71517a11-d415-4ea3-9ff6-1cc54a839811
# cached_votes_total                              0
# identifications_most_agree                      True
# species_guess                                   Euphorbia resinifera
# identifications_most_disagree                   False
# tags                                            []
# positional_accuracy                             9
# comments_count                                  0
# site_id                                         1
# license_code                                    0
# quality_metrics                                 [{'id': 8861907, 'user_id': 5448878, 'metric': 'wild', 'agree': False, 'user': {'id': 5448878, 'login': 'manu_dfz', 'spam': False, 'suspended': False, 'created_at': '2022-03-25T09:32:04+00:00', 'login_autocomplete': 'manu_dfz', 'login_exact': 'manu_dfz', 'name': 'emmanuel defossez', 'name_autocomplete': 'emmanuel defossez', 'orcid': None, 'icon': 'https://static.inaturalist.org/attachments/users/icons/5448878/thumb.jpeg?1653601471', 'observations_count': 621, 'identifications_count': 26, 'journal_posts_count': 0, 'activity_count': 647, 'species_count': 377, 'universal_search_rank': 621, 'roles': [], 'site_id': None, 'icon_url': 'https://static.inaturalist.org/attachments/users/icons/5448878/medium.jpeg?1653601471'}}]
# public_positional_accuracy                      9
# reviewed_by                                     [933540, 1378031, 5448878]
# oauth_application_id                            2
# flags                                           []
# created_at                                      2022-03-25 09:34:27 +0100
# description                                     Jardin botanique fribourg
# project_ids_with_curator_id                     []
# updated_at                                      2022-05-05 18:47:30 +0200
# sounds                                          []
# place_ids                                       [7236, 12684, 51962, 59614, 67952, 80627, 81490, 96372, 97391, 97931, 108692, 156646, 180732]
# captive                                         True
# ident_taxon_ids                                 [48460, 47126, 211194, 47125, 47124, 51820, 51821, 779191, 1244656, 1244731, 51822, 792725, 792732, 337712]
# outlinks                                        []
# faves_count                                     0
# ofvs
# num_identification_agreements                   1
# comments                                        []
# map_scale                                       0
# uri                                             https://www.inaturalist.org/observations/109442071
# project_ids                                     []
# community_taxon_id                              337712
# owners_identification_from_vision               False
# identifications_count                           1
# obscured                                        False
# num_identification_disagreements                0
# geoprivacy
# location                                        [46.79323042, 7.15587558]
# votes                                           []
# spam                                            False
# mappable                                        True
# identifications_some_agree                      True
# project_ids_without_curator_id                  []
# place_guess                                     Fribourg, Suisse
# identifications                                 [{'244361550': 337712}, {'257126442': 337712}]
# project_observations                            []
# photos                                          [{'184457357': 'https://static.inaturalist.org/photos/184457357/square.jpeg'}]
# faves                                           []
# non_owner_ids
# observed_on                                     2022-03-25 10:33:03 +0100
# photo_url                                       https://static.inaturalist.org/photos/184457357/square.jpeg
# taxon_is_active                                 True
# taxon_ancestry                                  48460/47126/211194/47125/47124/51820/51821/779191/1244656/1244731/51822/792725/792732
# taxon_min_species_ancestry                      48460,47126,211194,47125,47124,51820,51821,779191,1244656,1244731,51822,792725,792732,337712
# taxon_endemic                                   False
# taxon_iconic_taxon_id                           47126
# taxon_min_species_taxon_id                      337712
# taxon_threatened                                False
# taxon_rank_level                                10
# taxon_introduced                                False
# taxon_native                                    False
# taxon_parent_id                                 792732
# taxon_name                                      Euphorbia resinifera
# taxon_rank                                      species
# taxon_extinct                                   False
# taxon_id                                        337712
# taxon_ancestor_ids                              [48460, 47126, 211194, 47125, 47124, 51820, 51821, 779191, 1244656, 1244731, 51822, 792725, 792732, 337712]
# taxon_photos_locked                             False
# taxon_taxon_schemes_count                       1
# taxon_wikipedia_url                             https://en.wikipedia.org/wiki/Euphorbia_resinifera
# taxon_current_synonymous_taxon_ids              0
# taxon_created_at                                2013-12-03 22:27:34 +0100
# taxon_taxon_changes_count                       0
# taxon_complete_species_count
# taxon_universal_search_rank                     106
# taxon_observations_count                        106
# taxon_flag_counts_resolved                      0
# taxon_flag_counts_unresolved                    0
# taxon_atlas_id                                  0
# taxon_default_photo_id                          60554523
# taxon_default_photo_license_code                cc-by-nc
# taxon_default_photo_attribution                 (c) Matthieu Gauvain, some rights reserved (CC BY-NC), uploaded by Matthieu Gauvain
# taxon_default_photo_url                         https://inaturalist-open-data.s3.amazonaws.com/photos/60554523/square.jpeg
# taxon_default_photo_original_dimensions_height  1536
# taxon_default_photo_original_dimensions_width   2048
# taxon_default_photo_flags                       []
# taxon_default_photo_square_url                  https://inaturalist-open-data.s3.amazonaws.com/photos/60554523/square.jpeg
# taxon_default_photo_medium_url                  https://inaturalist-open-data.s3.amazonaws.com/photos/60554523/medium.jpeg
# taxon_iconic_taxon_name                         Plantae
# taxon_preferred_common_name                     Resin spurge
# preferences_prefers_community_taxon
# geojson_coordinates                             [7.15587558, 46.79323042]
# geojson_type                                    Point
# user_site_id                                    0
# user_created_at                                 2022-03-25 09:32:04 +0100
# user_id                                         5448878
# user_login                                      manu_dfz
# user_spam                                       False
# user_suspended                                  False
# user_login_autocomplete                         manu_dfz
# user_login_exact                                manu_dfz
# user_name                                       emmanuel defossez
# user_name_autocomplete                          emmanuel defossez
# user_orcid
# user_icon                                       https://static.inaturalist.org/attachments/users/icons/5448878/thumb.jpeg?1653601471
# user_observations_count                         621
# user_identifications_count                      26
# user_journal_posts_count                        0
# user_activity_count                             647
# user_species_count                              377
# user_universal_search_rank                      621
# user_roles                                      []
# user_icon_url                                   https://static.inaturalist.org/attachments/users/icons/5448878/medium.jpeg?1653601471
# taxon_default_photo
# taxon_conservation_status_place_id
# taxon_conservation_status_source_id
# taxon_conservation_status_user_id
# taxon_conservation_status_authority             0
# taxon_conservation_status_status                0
# taxon_conservation_status_status_name           0
# taxon_conservation_status_geoprivacy            0
# taxon_conservation_status_iucn                  0
# observed_on_details
# created_time_zone                               Etc/UTC
# observed_time_zone                              Etc/UTC
# time_zone_offset                                +00:00
# observed_on_string                              25.03.2022 10:33
# created_at_details_date
# created_at_details_week
# created_at_details_month
# created_at_details_hour
# created_at_details_year
# created_at_details_day
# swiped_loc                                      (7.15587558, 46.79323042)
# emi_external_id                                 0
